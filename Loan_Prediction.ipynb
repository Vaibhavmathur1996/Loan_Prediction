# %%
import numpy as np
import pandas as pd
from pandas import Series , DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import KFold
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split


from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

logreg = LogisticRegression()

# %%
train = pd.read_csv('/home/vaibhavmathur/Downloads/Loan_Prediction/train.csv')
test = pd.read_csv('/home/vaibhavmathur/Downloads/Loan_Prediction/test.csv')

# %%
train.head()
#test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train['LoanAmount'].fillna(train['LoanAmount'].mean() , inplace = True)
test['LoanAmount'].fillna(test['LoanAmount'].mean() , inplace = True)

# %%
train.describe()
test.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  367.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   60.946040         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  101.000000        360.000000
# 50%        3786.000000        1025.000000  126.000000        360.000000
# 75%        5060.000000        2430.500000  157.500000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].median() , inplace = True)
test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].median() , inplace = True)

# %%
train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.410423
# std        6109.041673        2926.248369   84.037468         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train['Credit_History'].fillna(train['Credit_History'].median() , inplace = True)
test['Credit_History'].fillna(test['Credit_History'].median() , inplace = True)

# %%
test.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  367.000000        367.000000
# mean       4805.599455        1569.577657  136.132597        342.822888
# std        4910.685399        2334.232099   60.946040         64.658402
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  101.000000        360.000000
# 50%        3786.000000        1025.000000  126.000000        360.000000
# 75%        5060.000000        2430.500000  157.500000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      367.000000
# mean         0.839237
# std          0.367814
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train['Gender'].replace(['Male' , 'Female'] , [0 , 1] , inplace = True)
test['Gender'].replace(['Male' , 'Female'] , [0 , 1] , inplace = True)

# %%
train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002     0.0      No          0      Graduate            No
# 1    LP001003     0.0     Yes          1      Graduate            No
# 2    LP001005     0.0     Yes          0      Graduate           Yes
# 3    LP001006     0.0     Yes          0  Not Graduate            No
# 4    LP001008     0.0      No          0      Graduate            No
# 5    LP001011     0.0     Yes          2      Graduate           Yes
# 6    LP001013     0.0     Yes          0  Not Graduate            No
# 7    LP001014     0.0     Yes         3+      Graduate            No
# 8    LP001018     0.0     Yes          2      Graduate            No
# 9    LP001020     0.0     Yes          1      Graduate            No
# 10   LP001024     0.0     Yes          2      Graduate            No
# 11   LP001027     0.0     Yes          2      Graduate           NaN
# 12   LP001028     0.0     Yes          2      Graduate            No
# ...

# %%
train['Gender'].fillna(train['Gender'].median() , inplace = True)
test['Gender'].fillna(test['Gender'].median() , inplace = True)

# %%
train['Married'].replace(['Yes' , 'No'] , [0 , 1] ,inplace = True)
test['Married'].replace(['Yes' , 'No'] , [0 , 1] ,inplace = True)

# %%
train['Married'].fillna(train['Married'].median() , inplace = True)
test['Married'].fillna(test['Married'].median() , inplace = True)

# %%
train.Education.unique()
test.Education.unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
train['Education'].replace(['Graduate' , 'Not Graduate'], [0 ,1 ] ,inplace = True)
test['Education'].replace(['Graduate' , 'Not Graduate'], [0 ,1 ] ,inplace = True)

# %%
train.Self_Employed.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
train['Self_Employed'].replace(['Yes' , 'No'] , [0 , 1] , inplace = True)
test['Self_Employed'].replace(['Yes' , 'No'] , [0 , 1] , inplace = True)

# %%
train.describe()
#test.describe()
# Out:
#            Gender     Married   Education  Self_Employed  ApplicantIncome  \
# count  614.000000  614.000000  614.000000     582.000000       614.000000
# mean     0.182410    0.346906    0.218241       0.859107      5403.459283
# std      0.386497    0.476373    0.413389       0.348211      6109.041673
# min      0.000000    0.000000    0.000000       0.000000       150.000000
# 25%      0.000000    0.000000    0.000000       1.000000      2877.500000
# 50%      0.000000    0.000000    0.000000       1.000000      3812.500000
# 75%      0.000000    1.000000    0.000000       1.000000      5795.000000
# max      1.000000    1.000000    1.000000       1.000000     81000.000000
#
#        CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# count         614.000000  614.000000        614.000000      614.000000
# mean         1621.245798  146.412162        342.410423        0.855049
# std          2926.248369   84.037468         64.428629        0.352339
# ...

# %%
train['Self_Employed'].fillna(train['Self_Employed'].median() , inplace = True)
test['Self_Employed'].fillna(test['Self_Employed'].median() , inplace = True)

# %%
train.describe()
test.describe()
# Out:
#            Gender     Married   Education  Self_Employed  ApplicantIncome  \
# count  367.000000  367.000000  367.000000     367.000000       367.000000
# mean     0.190736    0.365123    0.228883       0.899183      4805.599455
# std      0.393417    0.482122    0.420687       0.301498      4910.685399
# min      0.000000    0.000000    0.000000       0.000000         0.000000
# 25%      0.000000    0.000000    0.000000       1.000000      2864.000000
# 50%      0.000000    0.000000    0.000000       1.000000      3786.000000
# 75%      0.000000    1.000000    0.000000       1.000000      5060.000000
# max      1.000000    1.000000    1.000000       1.000000     72529.000000
#
#        CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# count         367.000000  367.000000        367.000000      367.000000
# mean         1569.577657  136.132597        342.822888        0.839237
# std          2334.232099   60.946040         64.658402        0.367814
# ...

# %%
train['Dependents'].replace(['3+'] , [3] , inplace = True)
test['Dependents'].replace(['3+'] , [3] , inplace = True)

# %%
train['Dependents'].fillna(train['Dependents'].median() , inplace = True)
test['Dependents'].fillna(test['Dependents'].median() , inplace = True)

# %%
train.describe()
test.describe()
# Out:
#            Gender     Married   Education  Self_Employed  ApplicantIncome  \
# count  367.000000  367.000000  367.000000     367.000000       367.000000
# mean     0.190736    0.365123    0.228883       0.899183      4805.599455
# std      0.393417    0.482122    0.420687       0.301498      4910.685399
# min      0.000000    0.000000    0.000000       0.000000         0.000000
# 25%      0.000000    0.000000    0.000000       1.000000      2864.000000
# 50%      0.000000    0.000000    0.000000       1.000000      3786.000000
# 75%      0.000000    1.000000    0.000000       1.000000      5060.000000
# max      1.000000    1.000000    1.000000       1.000000     72529.000000
#
#        CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# count         367.000000  367.000000        367.000000      367.000000
# mean         1569.577657  136.132597        342.822888        0.839237
# std          2334.232099   60.946040         64.658402        0.367814
# ...

# %%
train.Dependents.unique()
test.Dependents.unique()
# Out:
# array(['0', '1', '2', 3, 0.0], dtype=object)

# %%
train['Dependents'].replace(['0' , '1' , '2' , 0.0] , [0 ,1 ,2 , 0 ] , inplace = True)
test['Dependents'].replace(['0' , '1' , '2' , 0.0] , [0 ,1 ,2 , 0 ] , inplace = True)

# %%
train.Dependents.unique()
test.Dependents.unique()
# Out:
# array([0, 1, 2, 3])

# %%
train.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  614.000000  614.000000  614.000000  614.000000     614.000000
# mean     0.182410    0.346906    0.744300    0.218241       0.866450
# std      0.386497    0.476373    1.009623    0.413389       0.340446
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      0.000000    0.000000    0.000000    0.000000       1.000000
# 50%      0.000000    0.000000    0.000000    0.000000       1.000000
# 75%      0.000000    1.000000    1.000000    0.000000       1.000000
# max      1.000000    1.000000    3.000000    1.000000       1.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.410423
# std        6109.041673        2926.248369   84.037468         64.428629
# ...

# %%
train.Loan_Status.unique()
#test.Loan_Status.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
train
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002     0.0      1.0           0          0            1.0
# 1    LP001003     0.0      0.0           1          0            1.0
# 2    LP001005     0.0      0.0           0          0            0.0
# 3    LP001006     0.0      0.0           0          1            1.0
# 4    LP001008     0.0      1.0           0          0            1.0
# 5    LP001011     0.0      0.0           2          0            0.0
# 6    LP001013     0.0      0.0           0          1            1.0
# 7    LP001014     0.0      0.0           3          0            1.0
# 8    LP001018     0.0      0.0           2          0            1.0
# 9    LP001020     0.0      0.0           1          0            1.0
# 10   LP001024     0.0      0.0           2          0            1.0
# 11   LP001027     0.0      0.0           2          0            1.0
# 12   LP001028     0.0      0.0           2          0            1.0
# ...

# %%
train.Property_Area.unique()
test.Property_Area.unique()
# Out:
# array(['Urban', 'Semiurban', 'Rural'], dtype=object)

# %%
#train['Property_Area'].replace()
mylist = list(train.select_dtypes(include = ['object']).columns)
mylist
#train['Property_Area'].replace()
mylist1 = list(test.select_dtypes(include = ['object']).columns)
mylist1
# Out:
# ['Loan_ID', 'Property_Area']

# %%
mylist.remove('Loan_ID')
mylist1.remove('Loan_ID')

# %%
mylist.remove('Loan_Status')

# %%
train['Loan_Status'].replace(['Y' , 'N'] , [1,0] ,inplace = True)

# %%
train.Loan_Status.unique()
# Out:
# array([1, 0])

# %%
dummies = pd.get_dummies(train[mylist] , prefix = mylist)
train.drop(mylist , axis =1 , inplace = True)
train = pd.concat([train , dummies], axis = 1)

dummies1 = pd.get_dummies(test[mylist1] , prefix = mylist1)
test.drop(mylist1 , axis =1 , inplace = True)
test = pd.concat([test , dummies1], axis = 1)

# %%
train
train.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  614.000000  614.000000  614.000000  614.000000     614.000000
# mean     0.182410    0.346906    0.744300    0.218241       0.866450
# std      0.386497    0.476373    1.009623    0.413389       0.340446
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      0.000000    0.000000    0.000000    0.000000       1.000000
# 50%      0.000000    0.000000    0.000000    0.000000       1.000000
# 75%      0.000000    1.000000    1.000000    0.000000       1.000000
# max      1.000000    1.000000    3.000000    1.000000       1.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.410423
# std        6109.041673        2926.248369   84.037468         64.428629
# ...

# %%
A = train
A1 = test

# %%
B = A['Loan_Status']
A = A.drop(['Loan_ID' ] , axis = 1)
A = A.drop(['Loan_Status' ] , axis = 1)
A

A1 = A1.drop(['Loan_ID' ] , axis = 1)
A1
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       0.0        0           0          0            1.0             5720
# 1       0.0        0           1          0            1.0             3076
# 2       0.0        0           2          0            1.0             5000
# 3       0.0        0           2          0            1.0             2340
# 4       0.0        1           0          1            1.0             3276
# 5       0.0        0           0          1            0.0             2165
# 6       1.0        1           1          1            1.0             2226
# 7       0.0        0           2          1            1.0             3881
# 8       0.0        0           2          0            1.0            13633
# 9       0.0        1           0          1            1.0             2400
# 10      0.0        1           0          1            1.0             3091
# ...

# %%
#A1 = train[cols]
#A1
#train
a = test.Loan_ID

# %%
rfe = RFE(logreg, 5)
rfe = rfe.fit(A, B )
print(rfe.support_)
print(rfe.ranking_)

#Gender Married Education Self_Employed Credit_History Property_Area_Rural Property_Area_Semiurban Property_Area_Urban
# Out:
# [False  True False  True False False False False False  True  True False
#   True]
# [4 1 5 1 3 9 8 6 7 1 1 2 1]

# %%
A.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area_Rural',
#        'Property_Area_Semiurban', 'Property_Area_Urban'],
#       dtype='object')

# %%
#A = A.drop(['Loan_Status'] , axis = 1)



X_train, X_test, y_train, y_test = train_test_split(A, B, test_size=0.3, random_state=0)#
#from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
#cols = [ 'Married','Education', 'Credit_History' ,'Property_Area_Rural', 'Property_Area_Urban' ,]
cols = ['Married']

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
X_test.head()
# Out:
# Accuracy of logistic regression classifier on test set: 0.83
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 454     0.0      1.0           0          0            0.0             7085
# 52      1.0      1.0           0          0            1.0             4230
# 536     0.0      0.0           0          0            1.0             6133
# 469     0.0      0.0           0          0            1.0             4333
# 55      0.0      0.0           2          0            1.0             2708
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 454                0.0        84.0             360.0             1.0
# 52                 0.0       112.0             360.0             1.0
# 536             3906.0       324.0             360.0             1.0
# 469             2451.0       110.0             360.0             1.0
# 55              1167.0        97.0             360.0             1.0
#
# ...

# %%
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
kfold = model_selection.KFold(n_splits=10, random_state=7)
modelCV = LogisticRegression()
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, X_train, y_train, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average accuracy: 0.800

# %%
logreg.fit(A[cols],B)

pred = logreg.predict(A1[cols])
#pred.replace([0 , 1] , ['N' , 'Y'] , inplace = True)

# %%
#X, y = make_classification(n_samples=1000, n_features=4,n_informative=2, n_redundant=0,random_state=0, shuffle=False)
from sklearn.ensemble import RandomForestClassifier


clf = RandomForestClassifier(max_depth=5, random_state=0)
clf.fit(A[cols],B)
clf_pred = clf.predict(A1[cols])

# %%
outdf = pd.DataFrame({"Loan_ID" : a , "Loan_Status" : clf_pred})
outdf['Loan_Status'].replace([0 , 1] , ['N' , 'Y'] , inplace = True)
outdf.to_csv("LoanRF.csv")
